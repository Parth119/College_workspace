# %%
from sqlalchemy import create_engine

import pandas as pd

connection=create_engine('postgresql://postgres:htrap@localhost:5432/htrap_db',echo =True)

print("Connection Established...")

df=pd.read_sql_query('SELECT * FROM public."Information"',connection)

print(df)
# Out:
# Connection Established...
# 2021-10-19 00:19:45,620 INFO sqlalchemy.engine.base.Engine select version()
# 2021-10-19 00:19:45,636 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:19:45,636 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2021-10-19 00:19:45,651 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:19:45,651 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-10-19 00:19:45,651 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:19:45,651 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-10-19 00:19:45,667 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:19:45,672 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2021-10-19 00:19:45,679 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:19:45,689 INFO sqlalchemy.engine.base.Engine SELECT * FROM public."Information"
# ...

# %%
import psycopg2
conn = psycopg2.connect(database = "htrap_db", user = "postgres", password = "htrap", host = "127.0.0.1", port = "5432") 
print ("Opened database successfully!")

cur = conn.cursor()

cur.execute('''CREATE TABLE College

(ID INT PRIMARY KEY NOT NULL,

NAME TEXT NOT NULL,

AGE INT NOT NULL,

ADDRESS CHAR(50),

ENROLLMENT BIGINT);''')

print("Table created successfully!")

SQL_Query = pd.read_sql_query(

'''select

id,

name,

enrollment

from college''', conn)

df = pd.DataFrame(SQL_Query, columns=['id','name','enrollment'])

df

conn.commit()

conn.close()
# Out:
# Opened database successfully!
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# <ipython-input-2-179210ab62b3> in <module>
#      15 ADDRESS CHAR(50),
#      16
# ---> 17 ENROLLMENT BIGINT);''')
#      18
#      19 print("Table created successfully!")
#
# DuplicateTable: relation "college" already exists

# %%
df=pd.read_sql_query('SELECT * FROM College',connection)

print(df)
# Out:
# 2021-10-19 00:19:55,488 INFO sqlalchemy.engine.base.Engine SELECT * FROM College
# 2021-10-19 00:19:55,491 INFO sqlalchemy.engine.base.Engine {}
#    id    name  age                    address    enrollment
# 0   1    Meet   20  Parvat patiya, Surat       190840131064
# 1   2  Rakesh   21  Parvat patiya, Surat       190840131012
# 2   3  Ruchit   20  KharvarNagar, Surat        190840131030
# 3   4    Yash   20  Gopitalaw, Surat           190840131025

# %%
import pandas as pd
from sqlalchemy.types import Integer, Text, String, DateTime
from sqlalchemy import create_engine

jobs_df= pd.read_csv("NYC_jobs.csv")

table_name = 'nyc_jobs'

engine = create_engine("postgresql://postgres:htrap@localhost:5432/htrap_db", echo=True)
jobs_df.to_sql(
table_name,
engine,
if_exists='replace',
index=False,
chunksize=500,
dtype={
    "job_id":Integer,
    "agency":Text,
    "business_title":Text,
    "job_category":Text,
    "salary_range_from":Integer,
    "salary_range_to":Integer,
    "salary_frequency":String(50),
    "work_location":Text,
    "division/work_unit":Text,
    "job_description":Text,
    "posting_date":DateTime,
    "posting_updated":DateTime
}
)

table_df = pd.read_sql_table(table_name,con=engine)
print(table_df.info())
# Out:
# 2021-10-19 00:20:01,359 INFO sqlalchemy.engine.base.Engine select version()
# 2021-10-19 00:20:01,362 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:20:01,367 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2021-10-19 00:20:01,369 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:20:01,375 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-10-19 00:20:01,379 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:20:01,384 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-10-19 00:20:01,388 INFO sqlalchemy.engine.base.Engine {}
# 2021-10-19 00:20:01,394 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2021-10-19 00:20:01,397 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
df=pd.read_sql_query('SELECT * FROM nyc_jobs',connection)

print(df)
# Out:
# 2021-10-19 00:20:12,474 INFO sqlalchemy.engine.base.Engine SELECT * FROM nyc_jobs
# 2021-10-19 00:20:12,490 INFO sqlalchemy.engine.base.Engine {}
#       Job ID                         Agency Posting Type  # Of Positions  \
# 0     172053   DEPT OF INFO TECH & TELECOMM     Internal               1
# 1     172546  DEPT OF HEALTH/MENTAL HYGIENE     External              12
# 2     172546  DEPT OF HEALTH/MENTAL HYGIENE     Internal              12
# 3     150760          DEPARTMENT OF FINANCE     Internal               1
# 4     150760          DEPARTMENT OF FINANCE     External               1
# ...      ...                            ...          ...             ...
# 4185  252690     DEPT OF PARKS & RECREATION     Internal               1
# 4186  252690     DEPT OF PARKS & RECREATION     External               1
# 4187  252690     DEPT OF PARKS & RECREATION     Internal               1
# 4188  253686  DEPT OF HEALTH/MENTAL HYGIENE     Internal               4
# ...

# %%
import pandas as pd

conn = psycopg2.connect(database = "htrap_db", user = "postgres", password = "htrap", host = "127.0.0.1", port = "5432")

SQL_Query = pd.read_sql(
'''select
id,
name,
enrollment
from college''', conn)

df = pd.DataFrame(SQL_Query, columns=['id','name','enrollment']) 
df
# Out:
#    id    name    enrollment
# 0   1    Meet  190840131064
# 1   2  Rakesh  190840131012
# 2   3  Ruchit  190840131030
# 3   4    Yash  190840131025

# %%
import pandas as pd

conn = psycopg2.connect(database = "htrap_db", user = "postgres", password = "htrap", host = "127.0.0.1", port = "5432")

SQL_Query = pd.read_sql(
'''select
id,
name,
age,
address,
enrollment
from public."Information"''', conn)

df = pd.DataFrame(SQL_Query, columns=['id','name','age','address','enrollment']) 
df
# Out:
#    id     name  age                 address    enrollment
# 0   1    Parth   19        singanpor, Surat  190840131004
# 1   2  Keertan   20           Adajan, Surat  190840131006
# 2   3   Vedant   20           Adajan, Surat  190840131014
# 3   4  Mustafa   20  Mandvi villege, Mandvi  190840131013

# %%
import pandas as pd

conn = psycopg2.connect(database = "htrap_db", user = "postgres", password = "htrap", host = "127.0.0.1", port = "5432")

print("Information Table")
SQL_Query = pd.read_sql(
'''select
id,
name,
age,
address,
enrollment
from public."Information"''', conn)

pf = pd.DataFrame(SQL_Query, columns=['id','name','age','address','enrollment']) 
pf

print("College Table")
SQL_Query = pd.read_sql(
'''select
id,
name,
enrollment
from college''', conn)

df = pd.DataFrame(SQL_Query, columns=['id','name','enrollment']) 
df
# Out:
# Information Table
# College Table
#    id    name    enrollment
# 0   1    Meet  190840131064
# 1   2  Rakesh  190840131012
# 2   3  Ruchit  190840131030
# 3   4    Yash  190840131025
